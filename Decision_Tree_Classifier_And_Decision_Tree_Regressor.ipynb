# %%
#DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
data=pd.read_csv("diabetes2.csv")
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

# %%
calssi=DecisionTreeClassifier()
calssi.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=calssi.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7047244094488189

# %%
from sklearn import tree

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(calssi,filled=True,max_depth=3)
plt.show()

# %%
#DecisionTree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
datas=pd.read_csv("Used Car Dataset.csv")
x=datas.iloc[:,10:]
y=datas.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

# %%
decision=DecisionTreeRegressor()

# %%
decision.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=decision.predict(X_test)
y_pred
# Out:
# array([1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
#        1.50761464e+01, 1.50761464e+01, 1.50761464e+01, 1.50761464e+01,
# ...

# %%
from sklearn.metrics import r2_score

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.9305757381530433

# %%
len(x.iloc[0])
# Out:
# 5

# %%
Adjusted_R2=1-(1-R2)*(len(y)-1)/(len(y)-len(x.iloc[0])-1)
Adjusted_R2
# Out:
# 0.9303513546305903
